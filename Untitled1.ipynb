# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_Cleaned.csv')

# %%
df.head()
# Out:
#                      Job Title              Salary Estimate  \
# 0          Data Science Intern  $84K-$109K (Glassdoor est.)
# 1          Data Science Intern  $84K-$109K (Glassdoor est.)
# 2      Senior Business Analyst  $84K-$109K (Glassdoor est.)
# 3       Data Analytics Analyst  $84K-$109K (Glassdoor est.)
# 4  Junior Quantitative Analyst  $84K-$109K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Science Intern\n\nJob Title\n\nData Scien...     4.6
# 1  Data Science – Summer Intern\n\nHow will this ...     3.4
# 2  About GoDaddy\n\nGoDaddy powers the world's la...     3.7
# 3  Ocean Spray believes that our employees are ou...     2.4
# 4  Primary Responsibilities:\nDevelopment and sup...     3.6
#
#                       Company Name        Location    Headquarters  \
# 0                    Blend360\n4.6    Columbia, MD      Newark, NJ
# 1  Remedy BPCI Partners, LLC.\n3.4  New York State     Norwalk, CT
# 2                     GoDaddy\n3.7      Austin, TX  Scottsdale, AZ
# 3                 Ocean Spray\n2.4   Lakeville, MA   Lakeville, MA
# 4         Calamos Investments\n3.6        Illinois  Naperville, IL
#
#                       Size  Founded  Type of ownership  ... min_salary  \
# 0      51 to 200 employees     2002  Company - Private  ...         84
# 1     201 to 500 employees     2011  Company - Private  ...         84
# 2  5001 to 10000 employees     1997   Company - Public  ...         84
# 3   1001 to 5000 employees     1930  Company - Private  ...         84
# 4     201 to 500 employees     2004  Company - Private  ...         84
#
#   max_salary avg_salary                   company_txt       job_state  \
# 0        109       96.5                    Blend360\n        Columbia
# 1        109       96.5  Remedy BPCI Partners, LLC.\n  New York State
# 2        109       96.5                     GoDaddy\n          Austin
# 3        109       96.5                 Ocean Spray\n       Lakeville
# 4        109       96.5         Calamos Investments\n        Illinois
#
#    some_state  age  python_yn  R_yn Spark
# 0           0   18          0     0     0
# 1           0    9          1     0     1
# 2           0   23          1     0     1
# 3           1   90          1     0     0
# 4           0   16          1     0     0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'some_state', 'age', 'python_yn', 'R_yn',
#        'Spark'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr' in title.lower():
        return 'jr'
    else: 
        return'na'

## titulo del trabajo y trato honorifico

## corecciòn al estado de los Angeles

## Corecciòn al tamaño de la descripciòn del trabajo

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    59
# analyst           46
# na                31
# data engineer     29
# manager           15
# director          13
# mle                7
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        168
# senior     32
# Name: seniority, dtype: int64

# %%
# corregir nombre del estado de los Angeles
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
df.drop('job_state', inplace = True, axis =1)

# %%
# Longitud de la descripcciòn del trabajo
df['desc_len'] = df['Job Description'].apply(lambda x: len(x)) #Trae el numero de caracteres por descripcciòn
df['desc_len']
# Out:
# 0      1281
# 1      3171
# 2      4679
# 3      2428
# 4      1515
#        ...
# 195    4819
# 196    3771
# 197    3987
# 198    6960
# 199    4753
# Name: desc_len, Length: 200, dtype: int64

# %%
df['Competitors']
# Out:
# 0                                                     -1
# 1                     Healthfirst (New York), naviHealth
# 2      Network Solutions, Weebly, Endurance Internati...
# 3                Welch's, Campbell Soup Company, PepsiCo
# 4                                                     -1
#                              ...
# 195                                                   -1
# 196                                                   -1
# 197                                                   -1
# 198                                                   -1
# 199                                                   -1
# Name: Competitors, Length: 200, dtype: object

# %%
# Competitor count
df['num_Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['num_Competitors']
# Out:
# 0      0
# 1      2
# 2      3
# 3      3
# 4      0
#       ..
# 195    0
# 196    0
# 197    0
# 198    0
# 199    0
# Name: num_Competitors, Length: 200, dtype: int64

# %%
#hourly wage to annual 
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if(x.hourly ==1) else x.min_salary, axis =1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if(x.hourly ==1) else x.max_salary, axis =1)

# %%
df[df.hourly ==1][['hourly','min_salary','max_salary']] #Detectamos y filtramos por hora = 1 si hay salarios x horas y multiplicamos x 2
# Out:
# Empty DataFrame
# Columns: [hourly, min_salary, max_salary]
# Index: []

# %%
df[df.hourly ==0][['hourly','min_salary','max_salary']] #Detectamos y filtramos por hora = 0 si hay salarios dias
# Out:
#      hourly  min_salary  max_salary
# 0         0          84         109
# 1         0          84         109
# 2         0          84         109
# 3         0          84         109
# 4         0          84         109
# ..      ...         ...         ...
# 195       0          71         117
# 196       0          71         117
# 197       0          71         117
# 198       0          71         117
# 199       0          71         117
#
# [200 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'some_state', 'age', 'python_yn', 'R_yn', 'Spark',
#        'job_simp', 'seniority', 'desc_len', 'num_Competitors'],
#       dtype='object')

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0                           Blend360
# 1         Remedy BPCI Partners, LLC.
# 2                            GoDaddy
# 3                        Ocean Spray
# 4                Calamos Investments
#                    ...
# 195        Recursion Pharmaceuticals
# 196                       MassMutual
# 197           Accuride International
# 198                       GlobalSign
# 199    American Axle & Manufacturing
# Name: company_txt, Length: 200, dtype: object

# %%
df.describe()
# Out:
#            Rating     Founded  hourly  employer_Provided  min_salary  \
# count  200.000000   200.00000   200.0              200.0  200.000000
# mean     3.660000  1807.42000     0.0                0.0   89.110000
# std      0.932926   554.22752     0.0                0.0   20.232267
# min     -1.000000    -1.00000     0.0                0.0   50.000000
# 25%      3.300000  1935.00000     0.0                0.0   84.000000
# 50%      3.700000  1990.00000     0.0                0.0   91.000000
# 75%      4.100000  2005.00000     0.0                0.0  105.000000
# max      5.000000  2017.00000     0.0                0.0  113.000000
#
#        max_salary  avg_salary  some_state         age   python_yn        R_yn  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   118.520000  103.815000    0.585000   40.710000    0.570000    0.015000
# std     23.273977   21.335399    0.493958   44.697261    0.496318    0.121857
# min     75.000000   62.500000    0.000000   -1.000000    0.000000    0.000000
# 25%    109.000000   96.500000    0.000000   11.750000    0.000000    0.000000
# 50%    117.000000  105.500000    1.000000   23.000000    1.000000    0.000000
# 75%    132.000000  117.500000    1.000000   52.000000    1.000000    0.000000
# max    151.000000  132.000000    1.000000  175.000000    1.000000    1.000000
#
#             Spark     desc_len  num_Competitors
# count  200.000000   200.000000       200.000000
# mean     0.185000  3938.155000         1.025000
# std      0.389272  1587.051589         1.368848
# min      0.000000   693.000000         0.000000
# 25%      0.000000  3059.000000         0.000000
# 50%      0.000000  3703.000000         0.000000
# 75%      0.000000  4798.000000         3.000000
# max      1.000000  9022.000000         4.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'some_state', 'age', 'python_yn', 'R_yn', 'Spark',
#        'job_simp', 'seniority', 'desc_len', 'num_Competitors'],
#       dtype='object')

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist() #graficamos la columna de acuerdo al numero de caracteres de la columna descripcciòn

# %%
df.boxplot(column = ['age','avg_salary','num_Competitors','Rating']) #graficamos las columnas

# %%
df[['age','avg_salary','num_Competitors','Rating','desc_len']].corr()
# Out:
#                       age  avg_salary  num_Competitors    Rating  desc_len
# age              1.000000   -0.021058         0.109190  0.027570  0.167535
# avg_salary      -0.021058    1.000000         0.198205  0.032825 -0.131578
# num_Competitors  0.109190    0.198205         1.000000  0.062173  0.046060
# Rating           0.027570    0.032825         0.062173  1.000000  0.054063
# desc_len         0.167535   -0.131578         0.046060  0.054063  1.000000

# %%
sns.heatmap(df[['age','avg_salary','num_Competitors','Rating','desc_len']].corr(), vmax=.12, center =0, square=True, linewidths=.6, cbar_kws={"shrink": .5})

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','num_Competitors','Rating','desc_len','num_Competitors']].corr(), vmax=.3, center =0, cmap = cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_txt', 'some_state','python_yn', 'R_yn', 'Spark',
       'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s total = %d" % (i, len(cat_num)))
    chart= sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location total = 117
# graph for Headquarters total = 114
# graph for Size total = 8
# graph for Type of ownership total = 10
# graph for Industry total = 46
# graph for Sector total = 21
# graph for Revenue total = 13
# graph for company_txt total = 166
# graph for some_state total = 2
# graph for python_yn total = 2
# graph for R_yn total = 2
# graph for Spark total = 2
# graph for job_simp total = 7
# graph for seniority total = 2

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s total = %d" % (i, len(cat_num)))
    chart= sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'some_state', 'age', 'python_yn', 'R_yn', 'Spark',
#        'job_simp', 'seniority', 'desc_len', 'num_Competitors'],
#       dtype='object')
